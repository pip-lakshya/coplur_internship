# %%
print("hello world")
# Out:
# hello world

# %%
pip install matplotlib

# %%
#lib
import matplotlib.pyplot as plt
x= [1,2,3,4,5,6]
y=[0,5,10,15,20,25]
plt.plot(x,y)
plt.show()

# %%
x=1;
while x==True:
    expression= eval(input("Enter an expression"))
    print(expression)
    if(expression==False):
        x=0
# Out:
# -2
# 0

# %%
file=open("example.txt",'a')
file.write("\nAppended text")
file.close()
file=open("example.txt",'r')
data=file.read()
print(data)
file.close()
# Out:
# Chacha vidhayak hai humare
# Append

# %%
str1= "My name is Lakshya , i am a student of CSE data science" 
str2=input("enter character for letter count")
count=0
for i in str1:
    if(i.lower()==str2.lower()):
        count+=1
print(count)
# Out:
# 12
