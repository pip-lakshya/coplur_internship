# %%
#1) Practise -Dictionary -Tuple -Set
dict={"Name":["Lakshya","Khushbu","Khushal"],"Age":[20,19,19]}
print(dict["Name"],dict["Age"])
dict["Name"][1]="Tanvi"
print(dict)
dict1 = {1: "Python", 2: "Java", 3: "C++", 4: "Dart"} 
dict2 = dict1.copy() 
print(dict2) 
dict1.clear() 
print(dict1) 
print(dict2.get(1)) 
print(dict2.items()) 
print(dict2.keys()) 
dict2.pop(4) 
print(dict2) 

tuple1 = (1, 2, 3, 4, 5)
print(tuple1)
print(tuple1[0])
tuple2 = tuple1[1:4]
print(tuple2)

set1 = {1, 2, 3, 4, 5}
set2 = {10, 20, 30, 40, 50}
print(set1,type(set1))
set1.add(6)
print(set1)
s1 = set1.union(set2)
print(s1)
s2=set1 | set2
print(s2)
# Out:
# ['Lakshya', 'Khushbu', 'Khushal'] [20, 19, 19]
# {'Name': ['Lakshya', 'Tanvi', 'Khushal'], 'Age': [20, 19, 19]}
# {1: 'Python', 2: 'Java', 3: 'C++', 4: 'Dart'}
# {}
# Python
# dict_items([(1, 'Python'), (2, 'Java'), (3, 'C++'), (4, 'Dart')])
# dict_keys([1, 2, 3, 4])
# {1: 'Python', 2: 'Java', 3: 'C++'}
# (1, 2, 3, 4, 5)
# 1
# (2, 3, 4)
# {1, 2, 3, 4, 5} <class 'set'>
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6, 40, 10, 50, 20, 30}
# {1, 2, 3, 4, 5, 6, 40, 10, 50, 20, 30}

# %%
#2) Write a function for basic math operations like add multiply substract divide and use this in your program, take 2 number input from user.
a=input("enter num1")
b=input("enter num2")
c=input("enter operation to perform")
def basicmath(a,b,c):
    print("num1:",a)
    print("num2:",b)
    result= eval(a+c+b)
    return result
result=basicmath(a,b,c)
print("Result:",result)
# Out:
# num1: 3
# num2: 5
# Result: -2

# %%
#3) Write a program to check Palindrome Number
a=input("enter number")
original=int(a)
reverse=a[::-1]
if reverse==a:
    print(f"{original} is a palindrome")
else:
    print(f"{original} is not a palindrome")
# Out:
# 124536 is not a palindrome
